# %%
from scipy.stats import chisquare,chi2_contingency
import pandas as pd
import numpy as np

# %% [markdown]
# #### Chi2_contingency test tells about the dependence of the variables. But it doesn't talk about the depth of the relation.
# ##### CramerV method is implemented using contigency table and chisquare value by finding phi squared(which is essential the normalised value of chi2)
# ##### Steps
# 1. Compute the contigency table (sometimes known as confusion matrix)
# 2. Calulate the Chi-squared value
# 3. Find the total number of records (n)
# 4. Find the phi-squared value by chi2/n
# 5. Get the shape of the confusion matrix r,k=confusion_matrix.shape
# 6. Correct for bais (Bais correction) by phi2_cor=max(0,phi2-((r-1)*(k-1))/n-1)
# 7. Apply corrections for r,k rcor=r-(r-1)**2/n-1; kcor=k-(k-1)**2/n-1
# 8. Compute the correlations using R=np.sqrt(phi2/(rcor-1)*(kcor-1))

# %%
df=pd.read_csv(r"/Users/karthikeya/Downloads/rgmx-ps-vtm (1)/data/02_intermediate/ps/attributes.csv")
df.head()
# Out:
#                     DESCRIPTION Branded/Private Label           Manufacturer  \
# 0         CALPOL S/F SUSP 100ML               Branded  Johnson & Johnson Ltd
# 1  ANADIN EX ASP/PRC CPLTS 16PK               Branded                 Haleon
# 2      CALPOL SIX PLUS S/F 80ML               Branded  Johnson & Johnson Ltd
# 3  NRFN CHLD S/F C/F SUSP 100ML               Branded      Reckitt Benckiser
# 4       TESCO PRCTML CPLTS 16PK         Private Label  Tesco Food Stores Ltd
#
#   Range/Trading Company                     Brand Number in a Pack  \
# 0                Calpol         Calpol Analgesics   Not Applicable
# 1                Anadin         Anadin Analgesics     16 in a Pack
# 2                Calpol         Calpol Analgesics   Not Applicable
# 3               Nurofen  Nurofen Child Analgesics   Not Applicable
# 4                 Tesco          Tesco Analgesics     16 in a Pack
#
#   Active_Ingredient    MANUFACTURER_NM       BRAND_NM  \
# 0       Paracetamol             MCNEIL         CALPOL
# 1         Compounds             HALEON         ANADIN
# 2       Paracetamol             MCNEIL         CALPOL
# 3         Ibuprofen  RECKITT BENCKISER        NUROFEN
# 4       Paracetamol      PRIVATE LABEL  PRIVATE LABEL
#
#                 SUBBRAND_NM  ... PARACETAMOL_AO IBUPROFEN_AO PRICE_TIER  \
# 0  CALPOL INFANT SUSPENSION  ...    PARACETAMOL           AO    Premium
# 1              ANADIN EXTRA  ...             AO           AO      Value
# 2            CALPOL SIXPLUS  ...    PARACETAMOL           AO    Premium
# 3      NUROFEN FOR CHILDREN  ...             AO    IBUPROFEN    Premium
# 4             PRIVATE LABEL  ...    PARACETAMOL           AO      Value
#
#                     Brand.1     BRAND_NM.1 Range/Trading Company_NEW  \
# 0         Calpol Analgesics         CALPOL     Johnson & Johnson Ltd
# 1         Anadin Analgesics         ANADIN                    Haleon
# 2         Calpol Analgesics         CALPOL     Johnson & Johnson Ltd
# 3  Nurofen Child Analgesics        NUROFEN         Reckitt Benckiser
# 4          Tesco Analgesics  PRIVATE LABEL                        PL
#
#    Unnamed: 24     Price PRICE_TIER_MANUAL_MAPPED       sales
# 0          NaN  0.190383               Mainstream   6524028.0
# 1          NaN  0.125147                    Value   2265611.0
# 2          NaN  0.190383               Mainstream   4669969.0
# 3          NaN  0.200080               Mainstream   3241569.0
# 4          NaN  0.036136                    Value  12497440.0
#
# [5 rows x 28 columns]

# %%
df.columns
# Out:
# Index(['DESCRIPTION', 'Branded/Private Label', 'Manufacturer',
#        'Range/Trading Company', 'Brand', 'Number in a Pack',
#        'Active_Ingredient', 'MANUFACTURER_NM', 'BRAND_NM', 'SUBBRAND_NM',
#        'PRODUCT_CATEGORY', 'PRODUCT_SUB_CATEGORY', 'GSL_PHARMACY',
#        'CHILD_ADULT', 'PL_AO', 'FORM_TYPE', 'PACK_SIZE', 'DRUG_SUBSTANCE',
#        'PARACETAMOL_AO', 'IBUPROFEN_AO', 'PRICE_TIER', 'Brand.1', 'BRAND_NM.1',
#        'Range/Trading Company_NEW', 'Unnamed: 24', 'Price',
#        'PRICE_TIER_MANUAL_MAPPED', 'sales'],
#       dtype='object')

# %%
#filtering the data
df=df.select_dtypes(include='object')
df=df[['Branded/Private Label','MANUFACTURER_NM','BRAND_NM','CHILD_ADULT','PRICE_TIER','FORM_TYPE','SUBBRAND_NM','PARACETAMOL_AO','IBUPROFEN_AO']]
df.head()
# Out:
#   Branded/Private Label    MANUFACTURER_NM       BRAND_NM CHILD_ADULT  \
# 0               Branded             MCNEIL         CALPOL       CHILD
# 1               Branded             HALEON         ANADIN       ADULT
# 2               Branded             MCNEIL         CALPOL       CHILD
# 3               Branded  RECKITT BENCKISER        NUROFEN       CHILD
# 4         Private Label      PRIVATE LABEL  PRIVATE LABEL       ADULT
#
#   PRICE_TIER FORM_TYPE               SUBBRAND_NM PARACETAMOL_AO IBUPROFEN_AO
# 0    Premium    LIQUID  CALPOL INFANT SUSPENSION    PARACETAMOL           AO
# 1      Value   CAPLETS              ANADIN EXTRA             AO           AO
# 2    Premium    LIQUID            CALPOL SIXPLUS    PARACETAMOL           AO
# 3    Premium    LIQUID      NUROFEN FOR CHILDREN             AO    IBUPROFEN
# 4      Value   TABLETS             PRIVATE LABEL    PARACETAMOL           AO

# %%
def cramerv(cm):
    n=cm.sum().sum()
    r,k=cm.shape
    chi2=chi2_contingency(cm)[0]
    phi2=chi2/n
    phi2_cor=max(0,phi2-((r-1)*(k-1))/n-1)
    r_cor=r-((r-1)**2/n-1)
    k_cor=k-((k-1)**2/n-1)
    if min(r_cor-1,k_cor-1)==0:
        return 0
    else:
        correlation=np.sqrt(phi2_cor/min(r_cor-1,k_cor-1))
        return correlation
    
def confusion_matrix(df):
    n=len(df.columns)
    confusion_matrix=pd.DataFrame(np.zeros((n,n)),index=df.columns,columns=df.columns)
    
    #calculate corelation for each cell
    for col1 in df.columns:
        for col2 in df.columns:
            cm=pd.crosstab(df[col1],df[col2])
            if col1==col2:
                confusion_matrix.loc[col1,col2]=1.0
            else:
                confusion_matrix.loc[col1,col2]=cramerv(cm)
    return confusion_matrix

# %%
confusion_matrix(df)
# Out:
#                        Branded/Private Label  MANUFACTURER_NM  BRAND_NM  \
# Branded/Private Label                    1.0         0.000000  0.000000
# MANUFACTURER_NM                          0.0         1.000000  0.888176
# BRAND_NM                                 0.0         0.888176  1.000000
# CHILD_ADULT                              0.0         0.000000  0.000000
# PRICE_TIER                               0.0         0.000000  0.000000
# FORM_TYPE                                0.0         0.000000  0.000000
# SUBBRAND_NM                              0.0         0.801392  0.843461
# PARACETAMOL_AO                           0.0         0.000000  0.000000
# IBUPROFEN_AO                             0.0         0.000000  0.000000
#
#                        CHILD_ADULT  PRICE_TIER  FORM_TYPE  SUBBRAND_NM  \
# Branded/Private Label          0.0         0.0        0.0     0.000000
# MANUFACTURER_NM                0.0         0.0        0.0     0.801392
# BRAND_NM                       0.0         0.0        0.0     0.843461
# CHILD_ADULT                    1.0         0.0        0.0     0.000000
# PRICE_TIER                     0.0         1.0        0.0     0.000000
# FORM_TYPE                      0.0         0.0        1.0     0.000000
# SUBBRAND_NM                    0.0         0.0        0.0     1.000000
# PARACETAMOL_AO                 0.0         0.0        0.0     0.000000
# IBUPROFEN_AO                   0.0         0.0        0.0     0.000000
#
#                        PARACETAMOL_AO  IBUPROFEN_AO
# Branded/Private Label             0.0           0.0
# MANUFACTURER_NM                   0.0           0.0
# BRAND_NM                          0.0           0.0
# CHILD_ADULT                       0.0           0.0
# PRICE_TIER                        0.0           0.0
# FORM_TYPE                         0.0           0.0
# SUBBRAND_NM                       0.0           0.0
# PARACETAMOL_AO                    1.0           0.0
# IBUPROFEN_AO                      0.0           1.0
